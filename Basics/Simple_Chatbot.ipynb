# %%
user_input = input()
# Out:
#  chatbot

# %%
print(user_input)
# Out:
# chatbot

# %%
print('Hello there i am chatbat!')

for i in range(5):
    user_input = input('you: ')
    if user_input == 'hi':
        print('Chatbot: Hi, how can i help you')
    
    elif user_input == 'who are you':
        print('Chatbot: I am your chatbot... do you remember me???')
    
    elif user_input == 'how are you':
        print('Chatbot: I am doing great... hope you are enjoying your leave.')
    
    elif user_input == 'which game do you like to play':
        print('Chatbot: I dont play any games. I like to assist humans')
    
    elif user_input == 'who is the founder of instagram?':
        print('Chatbot: Kevin System along with mike krieger')
    
    else:
        print('Chatbot: sorry!!! I did not understand you')
# Out:
# Hello there i am chatbat!
# you:  hi
# Chatbot: Hi, how can i help you
# you:  how are you
# Chatbot: I am doing great... hope you are enjoying your leave.
# you:  who are you
# Chatbot: I am your chatbot... do you remember me???
# you:  hi
# Chatbot: Hi, how can i help you
# you:  hi
# Chatbot: Hi, how can i help you
